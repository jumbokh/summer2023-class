# %% [markdown]
# # AQI API 資料應用

# %% [markdown]
# ## 實戰：空氣品質查詢器

# %%
import requests
url = "https://data.epa.gov.tw/api/v2/aqx_p_432?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=ImportDate%20desc&format=JSON"
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
print(r.text)

# %%
# datas = r.json()
# type(datas)
# datas.keys()
# datas['total']
for i in range(len(datas['records'])):
    print(datas['records'][i]['county'], end=",")
    print(datas['records'][i]['sitename'], end=",")
    print(datas['records'][i]['aqi'], end=",")
    print(datas['records'][i]['status'])

# %%
q = input("請輸入你要查詢的縣市:")
for i in range(len(datas['records'])):
    # if datas['records'][i]['county'] == q.replace("台","臺"):
    if q.replace("台","臺") in datas['records'][i]['county']:
        print(datas['records'][i]['county'], end=",")
        print(datas['records'][i]['sitename'], end=",")
        print(datas['records'][i]['aqi'], end=",")
        print(datas['records'][i]['status'])
# Out:
# 請輸入你要查詢的縣市:屏東
# 屏東縣,屏東,97,普通
# 屏東縣,潮州,85,普通
# 屏東縣,恆春,40,良好
# 屏東縣,屏東(琉球),59,普通
# 屏東縣,屏東(枋山),37,良好

# %% [markdown]
# ## 實戰：隨機小貓圖片
#
# https://api.thecatapi.com/v1/images/search

# %%
import requests
url = "https://api.thecatapi.com/v1/images/search"
r = requests.get(url)
datas = r.json()

# %%
datas[0]['url']
# Out:
# 'https://cdn2.thecatapi.com/images/a7e.jpg'

# %%
from IPython.display import HTML
HTML(f"<img src={datas[0]['url']}>")
# Out:
# <img src=https://cdn2.thecatapi.com/images/a7e.jpg>

# %%
import requests
from IPython.display import HTML

url = "https://api.thecatapi.com/v1/images/search"
r = requests.get(url)
datas = r.json()
HTML(f"<img src={datas[0]['url']}>")
# Out:
# <img src=https://cdn2.thecatapi.com/images/bgi.png>

# %% [markdown]
# ## 實戰：萌典-國語字典
#
# https://www.moedict.tw/uni/%E8%90%8C

# %%
import requests
url = 'https://www.moedict.tw/uni/%E4%B8%AD'
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
print(r.text)

# %%
datas = r.json()
type(datas)
# Out:
# dict

# %%
print('國字:', datas['title'])
print('部首:', datas['radical'])
print('筆劃:', datas['stroke_count'])
print()
for i in range(len(datas['heteronyms'])):
    print('注音:', datas['heteronyms'][i]['bopomofo'])
    print('拼音:', datas['heteronyms'][i]['pinyin'])
    print()

# %%
# 製作可以查詢字典的互動程式
# 程式顯示「請輸入要查詢的國字:」
# 完成顯示查詢結果

import requests
w = input("請輸入要查詢的國字:")
url = 'https://www.moedict.tw/uni/' + w
r = requests.get(url)
datas = r.json()
print('國字:', datas['title'])
print('部首:', datas['radical'])
print('筆劃:', datas['stroke_count'])
print()
for i in range(len(datas['heteronyms'])):
    print('注音:', datas['heteronyms'][i]['bopomofo'])
    print('拼音:', datas['heteronyms'][i]['pinyin'])
    print()

# %%
# 製作可以查詢字典的互動程式-用自訂函式的方法
# checkword(w)，回傳值即是查詢結果
# 程式顯示「請輸入要查詢的國字:」
# 完成顯示查詢結果

import requests

def checkword(w):
    url = 'https://www.moedict.tw/uni/' + w
    r = requests.get(url)
    datas = r.json()
    msg = '國字:' + datas['title'] + '\n'
    msg += '部首:' + datas['radical'] + '\n'
    msg += '筆劃:' + str(datas['stroke_count']) + '\n'
    for i in range(len(datas['heteronyms'])):
        msg += '注音:' + datas['heteronyms'][i]['bopomofo'] + '\n'
        msg += '拼音:' + datas['heteronyms'][i]['pinyin'] + '\n'
    return msg

w = input("請輸入要查詢的國字:")
print(checkword(w))

# %% [markdown]
# ## 將專案打包成 WebApp

# %%
# !pip install gradio

# %%
# !pip show gradio

# %%
# 製作可以查詢字典的WebAPP

import requests
import gradio as gr

def checkword(w):
    url = 'https://www.moedict.tw/uni/' + w
    r = requests.get(url)
    datas = r.json()
    msg = '國字:' + datas['title'] + '\n'
    msg += '部首:' + datas['radical'] + '\n'
    msg += '筆劃:' + str(datas['stroke_count']) + '\n'
    for i in range(len(datas['heteronyms'])):
        msg += '注音:' + datas['heteronyms'][i]['bopomofo'] + '\n'
        msg += '拼音:' + datas['heteronyms'][i]['pinyin'] + '\n'
    return msg

gui = gr.Interface(
    fn = checkword,
    inputs = 'text',
    outputs = 'text'
)
gui.launch(share=True)

# %% [markdown]
# # 實戰：ChatGPT聊天機器人app

# %%
import requests
api_key = "YOUR_API_KEY"
headers = {'Authorization':f'Bearer {api_key}'}
url = 'https://api.openai.com/v1/completions'
data = {
    'prompt':'愛情是什麼?',
    'model':'text-davinci-003',
    'temperature':0.5,
    'max_tokens':1024,
}
response = requests.post(url, json=data, headers = headers)
response
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# {"id":"cmpl-7JC0k7sR76Lnaq5wkrzWPtK1TIFTh","object":"text_completion","created":1684808758,"model":"text-davinci-003","choices":[{"text":"\n\n愛情是一種感情，指兩個人之間的深刻情感和熱情，可以是友誼，可以是愛情，也可以是家庭關係。愛情是以喜悅、歡喜、關懷、勇敢、支持和信任為基礎的一種情感。","index":0,"logprobs":null,"finish_reason":"stop"}],"usage":{"prompt_tokens":11,"completion_tokens":154,"total_tokens":165}}

# %%
datas = response.json()
print(datas['choices'][0]['text'])
# Out:
# 愛情是一種感情，指兩個人之間的深刻情感和熱情，可以是友誼，可以是愛情，也可以是家庭關係。愛情是以喜悅、歡喜、關懷、勇敢、支持和信任為基礎的一種情感。

# %%
import requests
api_key = "YOUR_API_KEY"
headers = {'Authorization':f'Bearer {api_key}'}
url = 'https://api.openai.com/v1/completions'

q = input('請輸入你的問題：')
data = {
    'prompt':q,
    'model':'text-davinci-003',
    'temperature':0.5,
    'max_tokens':1024,
}
response = requests.post(url, json=data, headers = headers)

datas = response.json()
print('既然你誠心誠意的發問，我就大發慈悲的回答你：')
print(datas['choices'][0]['text'].strip())
# Out:
# 請輸入你的問題：請問愛情是什麼?
# 既然你誠心誠意的發問，我就大發慈悲的回答你：
# 愛情是一種感情，一種對另一個人的深深的愛意，它可以是濃烈的，也可以是溫柔的，它可以帶來滿足，也可以帶來痛苦，它可以使人快樂，也可以使人難過，它是一種神奇的感情，對於每個人來說，它都是不同的。

# %%
# 製作成自訂函式
# askchatgpt(q)

import requests
api_key = "YOUR_API_KEY"

def askchatgpt(q):
    headers = {'Authorization':f'Bearer {api_key}'}
    url = 'https://api.openai.com/v1/completions'
    data = {
        'prompt':q,
        'model':'text-davinci-003',
        'temperature':0.5,
        'max_tokens':1024,
    }
    response = requests.post(url, json=data, headers = headers)
    datas = response.json()
    msg = '既然你誠心誠意的發問，我就大發慈悲的回答你：\n' 
    msg += datas['choices'][0]['text'].strip()
    return msg

q = input('請輸入你的問題：')    
print(askchatgpt(q))
# Out:
# 請輸入你的問題：請問誰是世界上最美麗的人
# 既然你誠心誠意的發問，我就大發慈悲的回答你：
# ？
#
# 這個問題沒有絕對的答案，因為美麗是一種主觀的看法，每個人對美麗的定義都不同。

# %%
# 製作成ChatGPT WebAPP

import requests
import gradio as gr
api_key = "YOUR_API_KEY"

def askchatgpt(q):
    headers = {'Authorization':f'Bearer {api_key}'}
    url = 'https://api.openai.com/v1/completions'
    data = {
        'prompt':q,
        'model':'text-davinci-003',
        'temperature':0.5,
        'max_tokens':1024,
    }
    response = requests.post(url, json=data, headers = headers)
    datas = response.json()
    msg = '既然你誠心誠意的發問，我就大發慈悲的回答你：\n' 
    msg += datas['choices'][0]['text'].strip()
    return msg

gr.Interface(
    fn = askchatgpt,
    title = "ChatGPT Web App",
    inputs = gr.Textbox(label='你要問什麼問題?'),
    outputs = gr.Textbox(label='我來回答你')
).launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://733ad8e6f7e0de7491.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://733ad8e6f7e0de7491.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # 使用Colab建置Web服務

# %% [markdown]
# ## 首次建置
#
# 在 Google Drive 下載 ngrok
# 1. **先連接Google Drive**
# 2. 新增ngrok-ssh目錄
# 3. 在目錄中下載ngrok(下載解壓縮)

# %%
# !mkdir -p /content/drive/MyDrive/ngrok-ssh
# %cd /content/drive/MyDrive/ngrok-ssh
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip -O ngrok-stable-linux-amd64.zip
# !unzip -u ngrok-stable-linux-amd64.zip

# %%
# 設定ngrok權限
# %cd /content/drive/MyDrive/ngrok-ssh
# !chmod +x ngrok
# Out:
# /content/drive/MyDrive/ngrok-ssh

# %%
# ngrok authtoken 安裝
# !/content/drive/MyDrive/ngrok-ssh/ngrok authtoken 'YOUR AUTHTOKEN'
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %% [markdown]
# ## flask-ngrok的使用

# %%
# !pip install flask-ngrok

# %%
from flask import Flask
from flask_ngrok import run_with_ngrok

app = Flask(__name__)
run_with_ngrok(app)

@app.route("/")
def hello():
    return "Hello World"

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://8279-34-150-149-16.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:04:47] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:04:47] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# # 建置第一個LINEBot
#
# https://github.com/line/line-bot-sdk-python

# %%
# !pip install line-bot-sdk

# %%
from flask import Flask, request, abort
from flask_ngrok import run_with_ngrok

from linebot import (
    LineBotApi, WebhookHandler
)
from linebot.exceptions import (
    InvalidSignatureError
)
from linebot.models import (
    MessageEvent, TextMessage, TextSendMessage,
)

app = Flask(__name__)
run_with_ngrok(app)

line_bot_api = LineBotApi('YOUR_ACCESS_TOKEN')
handler = WebhookHandler('YOUT_CHANNEL_SECRET')


@app.route("/callback", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        print("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessage)
def handle_message(event):
    line_bot_api.reply_message(
        event.reply_token,
        TextSendMessage(text=event.message.text))


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://2d7e-34-150-149-16.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:40:52] "GET / HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:40:53] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:41:09] "GET /callback HTTP/1.1" 405 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:42:05] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:42:55] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:43:14] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:43:21] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:43:38] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:43:51] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:47:06] "GET / HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:47:14] "GET /callback HTTP/1.1" 405 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:47:36] "POST /callback HTTP/1.1" 200 -

# %%
from flask import Flask, request, abort
from flask_ngrok import run_with_ngrok

from linebot import (
    LineBotApi, WebhookHandler
)
from linebot.exceptions import (
    InvalidSignatureError
)
from linebot.models import (
    MessageEvent, TextMessage, TextSendMessage,
)

import requests
api_key = "你的API Key"

def askchatgpt(q):
    headers = {'Authorization':f'Bearer {api_key}'}
    url = 'https://api.openai.com/v1/completions'
    data = {
        'prompt':q,
        'model':'text-davinci-003',
        'temperature':0.5,
        'max_tokens':1024,
    }
    response = requests.post(url, json=data, headers = headers)
    datas = response.json()
    msg = '既然你誠心誠意的發問，我就大發慈悲的回答你：\n' 
    msg += datas['choices'][0]['text'].strip()
    return msg

app = Flask(__name__)
run_with_ngrok(app)

line_bot_api = LineBotApi('YOUR_ACCESS_TOKEN')
handler = WebhookHandler('YOUT_CHANNEL_SECRET')


@app.route("/callback", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        print("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessage)
def handle_message(event):
    line_bot_api.reply_message(
        event.reply_token,
        TextSendMessage(text=askchatgpt(event.message.text)))
    
if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://8264-34-150-149-16.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:52:04] "GET / HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:52:04] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:52:10] "GET /callback HTTP/1.1" 405 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:52:24] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:52:50] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:52:54] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 03:53:15] "POST /callback HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2023 04:05:03] "POST /callback HTTP/1.1" 200 -
